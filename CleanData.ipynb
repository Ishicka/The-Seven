# %%
import pandas as pd

file_path = "./Resources/ZHomeValues.csv"

# %%
og_df = pd.read_csv(file_path)
#21000ish

# %%
#eliminated all na values
clean_df = og_df.dropna()
clean_df
#7769 Rows
# Out:
#              RegionName State           CountyName     1/31/2000  \
# 0              New York    NY        Queens County  241271.91010
# 1           Los Angeles    CA   Los Angeles County  225898.91480
# 2               Houston    TX        Harris County  101935.86000
# 3               Chicago    IL          Cook County  127686.70440
# 4           San Antonio    TX         Bexar County   96873.72714
# ...                 ...   ...                  ...           ...
# 21546  Mount Charleston    NV         Clark County  357957.87340
# 21547         Clearview    WV          Ohio County   81271.89886
# 21553       Tribes Hill    NY    Montgomery County   59175.01353
# 21557           Haskins    OH          Wood County  130919.69250
# 21582        Galesville    MD  Anne Arundel County  240183.52340
#
#           2/29/2000     3/31/2000     4/30/2000     5/31/2000     6/30/2000  \
# 0      242565.51480  243908.20830  246421.69310  248905.58150  251519.49080
# ...

# %%
columns = og_df.columns.to_list()
ten_years_back = columns.index("10/31/2013") 
Year2013_Year2023= ["RegionName", "State", "CountyName",*columns[ten_years_back:]]
Year2013_Year2023
back10years_df = og_df[Year2013_Year2023].dropna()
back10years_df
# Out:
#           RegionName State               CountyName    10/31/2013  \
# 0           New York    NY            Queens County  465982.96670
# 1        Los Angeles    CA       Los Angeles County  466375.02450
# 2            Houston    TX            Harris County  125063.07000
# 3            Chicago    IL              Cook County  155004.23870
# 4        San Antonio    TX             Bexar County  124307.83750
# ...              ...   ...                      ...           ...
# 21582     Galesville    MD      Anne Arundel County  444977.35650
# 21583   Hungry Horse    MT          Flathead County  117489.96650
# 21584  Kachemak City    AK  Kenai Peninsula Borough  279827.75770
# 21587  Stirling City    CA             Butte County   50761.47305
# 21592    Martin City    MT          Flathead County  194856.37090
#
#          11/30/2013    12/31/2013     1/31/2014     2/28/2014     3/31/2014  \
# 0      468598.29040  470111.47720  471177.58690  473005.94400  475479.82610
# ...
